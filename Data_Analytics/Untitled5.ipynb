# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping

# %% [markdown]
# img = iming.imread('C:\\Users\\Dell\\Desktop\\Data analytics\\Ros\\download (2).jpg')

# %%
img = mping.imread('C:\\Users\\Dell\\Desktop\\Data analytics\\Ros\\download (2).jpg')

# %%
imgplot=plt.imshow(img)

# %%
8
